# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Soru 1:
# * Kaggle'in 2020 yılı için üyeleriyle yaptığı anket sonuçlarını içeren ekteki "kaggle_survey_2020_responses.csv" dosyasını 2. satırı atlayarak ```survey``` adlı DataFrame'e okuyun.
# * İlk sütunu silin.
# * Q1, Q2, Q3, Q4, Q5 ve Q6 sütun isimlerini sırasıyla Age, Gender, Country, Education, Occupation ve Coding Experience olacak şekilde değiştirin.
# * Education, Occupation ve Coding Experience sütunlarından herhangi birisisinde ```NaN``` değeri olan satırları siliniz. Kaç satır silindi?
# * En son oluşan DataFrame'in satır ve sütun sayısını yazdırın.

# %%
import pandas as pd
survey = pd.read_csv("kaggle_survey_2020_responses.csv", skiprows = [1])
survey
# Out:
#        Time from Start to Finish (seconds)     Q1     Q2  \
# 0                                     1838  35-39    Man
# 1                                   289287  30-34    Man
# 2                                      860  35-39    Man
# 3                                      507  30-34    Man
# 4                                       78  30-34    Man
# ...                                    ...    ...    ...
# 20031                                  126  18-21    Man
# 20032                                  566  55-59  Woman
# 20033                                  238  30-34    Man
# 20034                                  625  22-24    Man
# 20035                                 1031  22-24    Man
#
#                                                       Q3  \
# 0                                               Colombia
# 1                               United States of America
# 2                                              Argentina
# ...

# %%
survey = survey.drop('Time from Start to Finish (seconds)', axis=1)
survey
# Out:
#           Q1     Q2                                                 Q3  \
# 0      35-39    Man                                           Colombia
# 1      30-34    Man                           United States of America
# 2      35-39    Man                                          Argentina
# 3      30-34    Man                           United States of America
# 4      30-34    Man                                              Japan
# ...      ...    ...                                                ...
# 20031  18-21    Man                                             Turkey
# 20032  55-59  Woman  United Kingdom of Great Britain and Northern I...
# 20033  30-34    Man                                             Brazil
# 20034  22-24    Man                                              India
# 20035  22-24    Man                                           Pakistan
#
#                                                       Q4  \
# ...

# %%
survey.rename(columns={'Q1':'Age','Q2':'Gender','Q3':'Country','Q4':'Education','Q5':'Occupation','Q6':'Coding Experience'}, inplace=True)
survey
# Out:
#          Age Gender                                            Country  \
# 0      35-39    Man                                           Colombia
# 1      30-34    Man                           United States of America
# 2      35-39    Man                                          Argentina
# 3      30-34    Man                           United States of America
# 4      30-34    Man                                              Japan
# ...      ...    ...                                                ...
# 20031  18-21    Man                                             Turkey
# 20032  55-59  Woman  United Kingdom of Great Britain and Northern I...
# 20033  30-34    Man                                             Brazil
# 20034  22-24    Man                                              India
# 20035  22-24    Man                                           Pakistan
#
#                                                Education  \
# ...

# %%
len(survey) - len(survey.dropna(subset= ['Education', 'Occupation', 'Coding Experience']))
# Out:
# 916

# %%
survey = survey.dropna(subset= ['Education', 'Occupation', 'Coding Experience'])
survey
# Out:
#          Age Gender                                            Country  \
# 0      35-39    Man                                           Colombia
# 1      30-34    Man                           United States of America
# 2      35-39    Man                                          Argentina
# 3      30-34    Man                           United States of America
# 4      30-34    Man                                              Japan
# ...      ...    ...                                                ...
# 20029  35-39    Man                                           Thailand
# 20032  55-59  Woman  United Kingdom of Great Britain and Northern I...
# 20033  30-34    Man                                             Brazil
# 20034  22-24    Man                                              India
# 20035  22-24    Man                                           Pakistan
#
#                Education                 Occupation Coding Experience  \
# ...

# %%
print("Satır sayısı:",survey.shape[0] ,"Sütun sayısı:",survey.shape[1])
# Out:
# Satır sayısı: 19120 Sütun sayısı: 354

# %% [markdown]
# ## Soru 2:
# Ankete katılanların yaş aralık dağılımını pasta grafiği ile gösteriniz.

# %%
survey['Age'].value_counts().plot(kind='pie');

# %% [markdown]
# ## Soru 3:
# Türkiye'den ankete katılanların eğitim seviyelerine göre sayılarını listeleyiniz.

# %%
survey[survey['Country']=='Turkey'].Education.value_counts()
# Out:
# Bachelor’s degree                                                    129
# Master’s degree                                                      111
# Doctoral degree                                                       50
# Some college/university study without earning a bachelor’s degree     15
# I prefer not to answer                                                 8
# Professional degree                                                    6
# No formal education past high school                                   3
# Name: Education, dtype: int64

# %% [markdown]
# ## Soru 4:
# Her bir yaş aralığı için en çok yapılan meslek ismini (```Occupation```) listeleyiniz.

# %%
survey.groupby(['Age'])['Occupation'].agg(pd.Series.mode)
# Out:
# Age
# 18-21           Student
# 22-24           Student
# 25-29           Student
# 30-34    Data Scientist
# 35-39    Data Scientist
# 40-44    Data Scientist
# 45-49             Other
# 50-54             Other
# 55-59             Other
# 60-69             Other
# 70+      Data Scientist
# Name: Occupation, dtype: object

# %% [markdown]
# ## Soru 5:
# * Her bir programlama dilinin kaç anket katılımcısı tarafından kullanıldığını bulup büyükten küçüğe sıralayınız.
# * Her bir programlama dilinin kaç ```Data Scientist``` tarafından kullanıldığını bulup büyükten küçüğe sıralayınız.
# * Her iki sonucu aynı figürde yan yana iki alt grafik (subplot) olarak gösteriniz. Grafiklere uygun birer başlık (```title```) atayınız.

# %%
survey.filter(regex='^Q7', axis=1)
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 0        Python         R       SQL         C       NaN       NaN  Javascript
# 1        Python         R       SQL       NaN       NaN       NaN         NaN
# 2           NaN       NaN       NaN       NaN       NaN      Java  Javascript
# 3        Python       NaN       SQL       NaN       NaN       NaN         NaN
# 4        Python       NaN       NaN       NaN       NaN       NaN         NaN
# ...         ...       ...       ...       ...       ...       ...         ...
# 20029       NaN       NaN       SQL         C       NaN       NaN         NaN
# 20032    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20033    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20034    Python       NaN       SQL         C       NaN      Java  Javascript
# 20035    Python       NaN       NaN       NaN       NaN       NaN         NaN
#
# ...

# %%
#df_5_1 : 5.soru 1.madde için
PLframe_5_1 = survey.filter(regex='^Q7', axis=1)
df_5_1 = pd.DataFrame(PLframe_5_1.count(axis=0))
df_5_1.index = PLframe_5_1.apply(pd.Series.mode, axis=0).iloc[0]
df_5_1.index.name = 'Programming Languages'
df_5_1.columns = ['Count']
df_5_1 = df_5_1.sort_values('Count',ascending=False)
df_5_1
# Out:
#                        Count
# Programming Languages
# Python                 15530
# SQL                     7535
# R                       4277
# C++                     3827
# Java                    3367
# C                       3315
# Javascript              2995
# MATLAB                  2217
# Other                   1945
# Bash                    1776
# Julia                    262
# None                     206
# Swift                    198

# %%
#df_5_2 : 5.soru 2.madde için
PLframe_5_2 = survey.groupby('Occupation').get_group("Data Scientist").filter(regex='^Q7', axis=1)
df_5_2 = pd.DataFrame(PLframe_5_2.count(axis=0))
df_5_2.index = PLframe_5_2.apply(pd.Series.mode, axis=0).iloc[0]
df_5_2.index.name = 'Programming Languages for Data Scientist'
df_5_2.columns = ['Count']
df_5_2 = df_5_2.sort_values('Count',ascending=False)
df_5_2
# Out:
#                                           Count
# Programming Languages for Data Scientist
# Python                                     2453
# SQL                                        1473
# R                                           975
# Bash                                        405
# C++                                         323
# Java                                        305
# Javascript                                  290
# C                                           247
# Other                                       245
# MATLAB                                      242
# Julia                                        71
# Swift                                        14
# None                                          5

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10,5))
df_5_1.Count.plot(ax=axes[0], kind='bar', ylabel ='Count');
axes[0].set_title('5.Soru 1.Madde');
df_5_2.Count.plot(ax=axes[1], kind='bar', ylabel ='Count');
axes[1].set_title('5.Soru 2.Madde');

# %% [markdown]
# ## Soru 6:
# Yatay eksende kodlama deneyimi, dikey eksende makine öğrenmesi metotlarını kullanan ```Data Scientist``` sayısı olacak şekilde bir sütun grafiği çiziniz.

# %%
df_6 = survey[(survey['Occupation'] == 'Data Scientist') & (survey['Q15'] != 'I do not use machine learning methods')][['Q15','Coding Experience']]
df_6
# Out:
#                 Q15 Coding Experience
# 3         3-4 years        5-10 years
# 8         2-3 years        5-10 years
# 21     Under 1 year         < 1 years
# 37        1-2 years         3-5 years
# 39        2-3 years         3-5 years
# ...             ...               ...
# 19988     4-5 years       10-20 years
# 19992     2-3 years         20+ years
# 20004    5-10 years       10-20 years
# 20005     4-5 years       10-20 years
# 20018     1-2 years         1-2 years
#
# [2593 rows x 2 columns]

# %%
import seaborn as sns
sns.catplot(x="Coding Experience", kind="count", palette="ch:.25", height=4.27, aspect=11.7/4.27, data=df_6);

# %% [markdown]
# ## Soru 7:
# * Yalnızca scikit-learn framework'ünü kullananların kullandıkları makine öğrenmesi algoritmalarının kullanıcı sayılarını büyükten küçüğe listeleyiniz.
# * Scikit-learn, tensorflow ve keras kütüphanelerini düzenli olarak kullanan kişi sayısı kaçtır?

# %%
df_7_1 = survey.dropna(subset=['Q16_Part_1']).filter(regex='^Q(16|17)', axis=1)
df_7_1
# Out:
#             Q16_Part_1     Q16_Part_2 Q16_Part_3 Q16_Part_4 Q16_Part_5  \
# 1        Scikit-learn     TensorFlow      Keras    PyTorch         NaN
# 3        Scikit-learn     TensorFlow      Keras         NaN        NaN
# 6        Scikit-learn             NaN        NaN   PyTorch    Fast.ai
# 8        Scikit-learn     TensorFlow      Keras    PyTorch         NaN
# 14       Scikit-learn             NaN        NaN        NaN        NaN
# ...                ...            ...        ...        ...        ...
# 20022    Scikit-learn     TensorFlow      Keras         NaN        NaN
# 20024    Scikit-learn             NaN     Keras    PyTorch         NaN
# 20025    Scikit-learn     TensorFlow      Keras    PyTorch         NaN
# 20032    Scikit-learn     TensorFlow      Keras    PyTorch         NaN
# 20034    Scikit-learn     TensorFlow      Keras    PyTorch         NaN
#
#       Q16_Part_6 Q16_Part_7  Q16_Part_8 Q16_Part_9 Q16_Part_10  ...  \
# ...

# %%
df_7_1_temp = df_7_1.filter(regex='^Q16').drop('Q16_Part_1',axis=1)
df_7_1_temp = df_7_1_temp[df_7_1_temp.isna().all(axis=1)]
df_7_1_onlyscikit = df_7_1.loc[df_7_1_temp.index]
df_7_1_onlyscikit
# Out:
#             Q16_Part_1 Q16_Part_2 Q16_Part_3 Q16_Part_4 Q16_Part_5 Q16_Part_6  \
# 24       Scikit-learn         NaN        NaN        NaN        NaN        NaN
# 27       Scikit-learn         NaN        NaN        NaN        NaN        NaN
# 73       Scikit-learn         NaN        NaN        NaN        NaN        NaN
# 110      Scikit-learn         NaN        NaN        NaN        NaN        NaN
# 119      Scikit-learn         NaN        NaN        NaN        NaN        NaN
# ...                ...        ...        ...        ...        ...        ...
# 20002    Scikit-learn         NaN        NaN        NaN        NaN        NaN
# 20003    Scikit-learn         NaN        NaN        NaN        NaN        NaN
# 20012    Scikit-learn         NaN        NaN        NaN        NaN        NaN
# 20014    Scikit-learn         NaN        NaN        NaN        NaN        NaN
# 20021    Scikit-learn         NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
#df_7 : 7.soru için
Onlyscikitframe_7_1 = df_7_1_onlyscikit.filter(regex='^Q17', axis=1)
df_7_1 = pd.DataFrame(Onlyscikitframe_7_1.count(axis=0))
df_7_1.index = Onlyscikitframe_7_1.apply(pd.Series.mode, axis=0).iloc[0]
df_7_1.index.name = 'ML Algorithms'
df_7_1.columns = ['Count']
df_7_1 = df_7_1.sort_values('Count',ascending=False)
df_7_1
# Out:
#                                                     Count
# ML Algorithms
# Linear or Logistic Regression                        1683
# Decision Trees or Random Forests                     1292
# Bayesian Approaches                                   428
# Gradient Boosting Machines (xgboost, lightgbm, ...    295
# Convolutional Neural Networks                         138
# None                                                  105
# Dense Neural Networks (MLPs, etc)                      68
# Recurrent Neural Networks                              67
# Other                                                  60
# Evolutionary Approaches                                38
# Transformer Networks (BERT, gpt-3, etc)                20
# Generative Adversarial Networks                         8

# %%
df_7_2 = survey[['Q16_Part_1','Q16_Part_2','Q16_Part_3']].dropna()
df_7_2
# Out:
#             Q16_Part_1     Q16_Part_2 Q16_Part_3
# 1        Scikit-learn     TensorFlow      Keras
# 3        Scikit-learn     TensorFlow      Keras
# 8        Scikit-learn     TensorFlow      Keras
# 17       Scikit-learn     TensorFlow      Keras
# 19       Scikit-learn     TensorFlow      Keras
# ...                ...            ...        ...
# 20018    Scikit-learn     TensorFlow      Keras
# 20022    Scikit-learn     TensorFlow      Keras
# 20025    Scikit-learn     TensorFlow      Keras
# 20032    Scikit-learn     TensorFlow      Keras
# 20034    Scikit-learn     TensorFlow      Keras
#
# [4406 rows x 3 columns]

# %%
df_7_2.shape[0]
# Out:
# 4406

# %% [markdown]
# ## Soru 8:
# * Ortalama yıllık maaşı en yüksek olan meslek (```Occupation```) nedir? ```Data Scientist``` kaçıncı sıradadır? **Not:** Aralık olarak verilen maaşların orta noktasını maaş değeri olarak alıp ```ConvertedComp``` isimli yeni bir sütun ekleyiniz.
# * ```Data Scientist``` olarak çalışanların ülke bazında ortalama yıllık maaşlarını büyükten küçüğe sıralayın, ilk 10 ülkeyi ve bu ülkelerdeki ortalama yıllık ```Data Scientist``` maaşlarını listeleyin.
# * 250’den fazla kişi çalışan kurumdakilerin ortalama maaşları ne kadardır?
# * Hesaplanan maaş (```ConvertedComp```) sütununu kullanarak ülke bazlı ortalama, standart sapma ve medyan değerlerinden oluşan bir dataframe oluşturun ve listeleyin. Türkiye kaçıncı sıradadır ve değeri kaçtır?

# %%
survey2 = survey.reset_index()

# %%
survey2['Q24']
# Out:
# 0                    NaN
# 1        100,000-124,999
# 2          15,000-19,999
# 3        125,000-149,999
# 4                    NaN
#               ...
# 19115      15,000-19,999
# 19116                NaN
# 19117             $0-999
# 19118             $0-999
# 19119             $0-999
# Name: Q24, Length: 19120, dtype: object

# %%
survey2['Q24'].unique()
# Out:
# array([nan, '100,000-124,999', '15,000-19,999', '125,000-149,999',
#        '70,000-79,999', '30,000-39,999', '90,000-99,999', '1,000-1,999',
#        '$0-999', '10,000-14,999', '150,000-199,999', '60,000-69,999',
#        '4,000-4,999', '> $500,000', '300,000-500,000', '40,000-49,999',
#        '25,000-29,999', '80,000-89,999', '7,500-9,999', '50,000-59,999',
#        '250,000-299,999', '5,000-7,499', '2,000-2,999', '20,000-24,999',
#        '200,000-249,999', '3,000-3,999'], dtype=object)

# %%
survey2['ConvertedComp'] = survey2['Q24']
survey2['ConvertedComp'] = survey2['ConvertedComp'].astype(str).map(lambda x: x.lstrip('>'))
survey2['ConvertedComp'] = survey2['ConvertedComp'].astype(str).map(lambda x: x.lstrip())
survey2['ConvertedComp'] = survey2['ConvertedComp'].astype(str).map(lambda x: x.lstrip('$'))
survey2['ConvertedComp'] = survey2['ConvertedComp'].astype(str).map(lambda x: x.replace(',',""))

# %%
survey2['ConvertedComp'].unique()
# Out:
# array(['nan', '100000-124999', '15000-19999', '125000-149999',
#        '70000-79999', '30000-39999', '90000-99999', '1000-1999', '0-999',
#        '10000-14999', '150000-199999', '60000-69999', '4000-4999',
#        '500000', '300000-500000', '40000-49999', '25000-29999',
#        '80000-89999', '7500-9999', '50000-59999', '250000-299999',
#        '5000-7499', '2000-2999', '20000-24999', '200000-249999',
#        '3000-3999'], dtype=object)

# %%
survey2['ConvertedComp'] = survey2['ConvertedComp'].astype(str).map(lambda x: " ".join(x.split("-")))
survey2['ConvertedComp']
# Out:
# 0                  nan
# 1        100000 124999
# 2          15000 19999
# 3        125000 149999
# 4                  nan
#              ...
# 19115      15000 19999
# 19116              nan
# 19117            0 999
# 19118            0 999
# 19119            0 999
# Name: ConvertedComp, Length: 19120, dtype: object

# %%
from tqdm import tqdm  
for i in tqdm(range(0,len(survey2['ConvertedComp']))):
    if survey2['ConvertedComp'][i] != 'nan':
        if " " in survey2['ConvertedComp'][i]:
            t = survey2['ConvertedComp'][i].split(" ")
            survey2['ConvertedComp'][i] = (int(t[0])+int(t[1]))/2
        else:
            survey2['ConvertedComp'][i] = int(survey2['ConvertedComp'][i])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 19120/19120 [00:08<00:00, 2376.10it/s]

# %%
survey2['ConvertedComp']
# Out:
# 0             nan
# 1        112499.5
# 2         17499.5
# 3        137499.5
# 4             nan
#            ...
# 19115     17499.5
# 19116         nan
# 19117       499.5
# 19118       499.5
# 19119       499.5
# Name: ConvertedComp, Length: 19120, dtype: object

# %%
import numpy as np
df_8_1 = survey2[survey2['ConvertedComp']!='nan'].groupby('Occupation')['ConvertedComp'].apply(np.mean).reset_index()
df_8_1.sort_values(by='ConvertedComp', ascending=False)
#data science görüldüğü üzere 2.sıradadır.
# Out:
#                    Occupation  ConvertedComp
# 7     Product/Project Manager   62362.216949
# 4              Data Scientist   54477.821518
# 3               Data Engineer   50225.113821
# 6                       Other   46755.972149
# 1       DBA/Database Engineer   45872.276786
# 8          Research Scientist   45399.797665
# 0            Business Analyst   39512.040560
# 9           Software Engineer   38562.467901
# 5   Machine Learning Engineer   37625.320806
# 10               Statistician   35626.520161
# 2                Data Analyst   28840.373810

# %%
df_8_2 = survey2[survey2['Occupation']=='Data Scientist']
df_8_2 = df_8_2[df_8_2['ConvertedComp']!='nan']
df_8_2 = df_8_2.groupby('Country')['ConvertedComp'].apply(np.mean).reset_index()
df_8_2.sort_values(by='ConvertedComp', ascending=False).head(10)
# Out:
#                                               Country  ConvertedComp
# 53                           United States of America  142609.330110
# 19                                             Israel  111979.520000
# 45                                        Switzerland  109230.269231
# 1                                           Australia  104318.958333
# 52  United Kingdom of Great Britain and Northern I...   89749.504587
# 12                                            Germany   79804.195312
# 18                                            Ireland   78499.500000
# 39                                          Singapore   76937.000000
# 6                                              Canada   74466.481132
# 47                                           Thailand   73707.875000

# %%
survey2['Q20'].unique()
# Out:
# array([nan, '10,000 or more employees', '1000-9,999 employees',
#        '250-999 employees', '0-49 employees', '50-249 employees'],
#       dtype=object)

# %%
df_8_3 = survey2[survey2['ConvertedComp']!='nan']
df_8_3 = df_8_3.loc[(df_8_3['Q20']=='10,000 or more employees')|(df_8_3['Q20']=='1000-9,999 employees')|(df_8_3['Q20']=='250-999 employees')]
df_8_3['ConvertedComp'].mean()
# Out:
# 56410.82901998097

# %% [markdown]
# Hesaplanan maaş (ConvertedComp) sütununu kullanarak
# ülke bazlı ortalama, standart sapma ve medyan değerlerinden oluşan bir dataframe oluşturun ve listeleyin.
# Türkiye kaçıncı sıradadır ve değeri kaçtır?

# %%
df_8_4 = survey2[survey2['ConvertedComp']!='nan']
df_8_4_grpd = df_8_4.groupby('Country')['ConvertedComp'].apply(np.var).reset_index()

df_8_4_grpd = df_8_4_grpd.rename(columns={'ConvertedComp': 'Var CovertedComp'})

df_8_4_grpd['Mean ConvertedComp'] = df_8_4.groupby('Country')['ConvertedComp'].apply(np.mean).reset_index()['ConvertedComp']
df_8_4_grpd['Median ConvertedComp'] = df_8_4.groupby('Country')['ConvertedComp'].apply(np.median).reset_index()['ConvertedComp']
df_8_4_grpd['Std ConvertedComp'] = df_8_4.groupby('Country')['ConvertedComp'].apply(np.std).reset_index()['ConvertedComp']

df_8_4_grpd
# Out:
#                                               Country  Var CovertedComp  \
# 0                                           Argentina      1.134555e+09
# 1                                           Australia      4.870708e+09
# 2                                          Bangladesh      4.831631e+07
# 3                                             Belarus      2.836952e+08
# 4                                             Belgium      7.955058e+09
# 5                                              Brazil      1.688254e+09
# 6                                              Canada      3.018149e+09
# 7                                               Chile      8.057835e+08
# 8                                               China      5.869431e+09
# 9                                            Colombia      2.625517e+08
# 10                                              Egypt      3.222551e+08
# 11                                             France      1.908168e+09
# ...

# %%
df_8_4_grpd[df_8_4_grpd['Country']=='Turkey']
#49.sıradadır (herhangi bir istatistiki sıra değildir. soruda da böyle bir sıralama istenmemiştir)
#değerler görülmektedir.
# Out:
#    Country  Var CovertedComp  Mean ConvertedComp  Median ConvertedComp  \
# 49  Turkey      1.900814e+09        16692.274096                8749.5
#
#     Std ConvertedComp
# 49       43598.321554

# %% [markdown]
# ## Soru 9:
# Lisans, yüksek lisans ve doktora mezunlarına ilişkin (ayrı ayrı); yatay eksende kodlama deneyimi (artan sırada olmalıdır), dikey eksende ortalama maaş bilgisi olacak şekilde tek bir çizgi grafiği çiziniz.

# %%
df_9 = survey2.loc[(survey2['Education']=='Bachelor’s degree')|(survey2['Education']=='Master’s degree')|(survey2['Education']=='Doctoral degree')]
df_9
# Out:
#        index    Age Gender                                            Country  \
# 0          0  35-39    Man                                           Colombia
# 1          1  30-34    Man                           United States of America
# 2          2  35-39    Man                                          Argentina
# 3          3  30-34    Man                           United States of America
# 4          4  30-34    Man                                              Japan
# ...      ...    ...    ...                                                ...
# 19115  20029  35-39    Man                                           Thailand
# 19116  20032  55-59  Woman  United Kingdom of Great Britain and Northern I...
# 19117  20033  30-34    Man                                             Brazil
# 19118  20034  22-24    Man                                              India
# 19119  20035  22-24    Man                                           Pakistan
#
# ...

# %%
df_9['Coding Experience'] = pd.Categorical(df_9['Coding Experience'], categories = ['< 1 years', 'I have never written code','1-2 years', '3-5 years', '5-10 years', '10-20 years', '20+ years'], ordered = True)

# %%
df_9 = df_9[df_9['ConvertedComp']!='nan']
df_9.groupby(['Coding Experience', 'Education'],sort=False)['ConvertedComp'].apply(np.mean).unstack().plot(kind='line', figsize=(10,7));

# %% [markdown]
# ## Soru 10:
# * Mesleklerdeki (Occupation) cinsiyet dağılımını, yatay yığılmış "stacked" sütun grafik olarak gösteriniz.
# * Her meslek (Occupation) için kadın oranını bulup büyükten küçüğe sıralayınız.
# * Şu anda çalışmayan kadın ve erkek oranlarını listeleyiniz.

# %%
df_10_1 = survey[['Occupation','Gender']]
df_10_1.groupby(['Occupation', 'Gender']).size().unstack().plot(kind='barh', stacked=True, figsize=(10,7));

# %%
df_10_2 = df_10_1.copy()
df_10_2['Gender'] = np.where(df_10_2['Gender'].str.contains('Woman', case=False, na = False), 1, 0)
df_10_2.groupby('Occupation')['Gender'].value_counts(normalize=True)
# 1: Woman, 0: Not woman
# Out:
# Occupation                 Gender
# Business Analyst           0         0.806616
#                            1         0.193384
# Currently not employed     0         0.773252
#                            1         0.226748
# DBA/Database Engineer      0         0.872000
#                            1         0.128000
# Data Analyst               0         0.764585
#                            1         0.235415
# Data Engineer              0         0.861111
#                            1         0.138889
# Data Scientist             0         0.835653
#                            1         0.164347
# Machine Learning Engineer  0         0.873832
#                            1         0.126168
# Other                      0         0.831977
#                            1         0.168023
# Product/Project Manager    0         0.886297
#                            1         0.113703
# Research Scientist         0         0.796915
#                            1         0.203085
# ...

# %%
df_10_3 = df_10_1[df_10_1['Occupation']=='Currently not employed']
df_10_3[df_10_3['Gender']=='Man'].shape[0] / df_10_3[df_10_3['Gender']=='Woman'].shape[0]
# 3 katlık bir oran vardır.
# Out:
# 3.3002680965147455

# %% [markdown]
# ## Soru 11:
#
# Ankete katılan kadınlardan ortalama çalışma süresi 3 yılın üzerinde olanlar için:
# * Kadın katılımcı sayısının en yüksek olduğu ülke hangisidir?
# * Türkiye'den ankete katılan kadınların eğitim durumlarını pasta grafiğinde gösteriniz.

# %%
df_11 = survey.loc[(survey['Coding Experience']=='20+ years')|(survey['Coding Experience']=='10-20 years')|(survey['Coding Experience']=='5-10 years')|(survey['Coding Experience']=='3-5 years')]
df_11 = survey[(survey['Gender'] == 'Woman')]
df_11
# Out:
#          Age Gender                                            Country  \
# 7      25-29  Woman                                              China
# 15     18-21  Woman                                              India
# 16     25-29  Woman                                              Other
# 20     22-24  Woman                                              India
# 22     55-59  Woman                                             Canada
# ...      ...    ...                                                ...
# 20013  30-34  Woman                                             Turkey
# 20014  18-21  Woman                                              India
# 20020  18-21  Woman                           United States of America
# 20026  22-24  Woman                                             Russia
# 20032  55-59  Woman  United Kingdom of Great Britain and Northern I...
#
#                Education               Occupation Coding Experience Q7_Part_1  \
# ...

# %%
df_11['Country'].value_counts()[:1]
# Out:
# India    1227
# Name: Country, dtype: int64

# %%
df_11[df_11['Country']=='Turkey']['Education'].value_counts().plot(kind='pie');

# %% [markdown]
# ## Soru 12:
# * 39. soru ile ilgili sütunlarda yer alan değerlerdeki parantez içi ifadeleri siliniz.
# * 18-21 yaş aralığında olan katılımcıların favori sosyal medya platformu nedir?

# %%
df_12_1 = survey.filter(regex='^Q39', axis=1).apply(lambda x: x.str.replace(r"\(.*\)",""))
df_12_1
# Out:
#       Q39_Part_1          Q39_Part_2 Q39_Part_3 Q39_Part_4      Q39_Part_5  \
# 0            NaN                 NaN        NaN    Kaggle              NaN
# 1       Twitter                  NaN    Reddit     Kaggle   Course Forums
# 2            NaN  Email newsletters         NaN    Kaggle              NaN
# 3            NaN                 NaN        NaN        NaN             NaN
# 4            NaN                 NaN        NaN        NaN             NaN
# ...          ...                 ...        ...        ...             ...
# 20029        NaN                 NaN        NaN        NaN             NaN
# 20032        NaN                 NaN        NaN        NaN             NaN
# 20033        NaN                 NaN        NaN        NaN             NaN
# 20034   Twitter                  NaN        NaN    Kaggle              NaN
# 20035        NaN                 NaN        NaN    Kaggle   Course Forums
#
#       Q39_Part_6 Q39_Part_7 Q39_Part_8             Q39_Part_9  \
# ...

# %%
filter_col = [col for col in survey if col.startswith('Q39')]
survey[filter_col] = df_12_1
survey[filter_col]
# Out:
#       Q39_Part_1          Q39_Part_2 Q39_Part_3 Q39_Part_4      Q39_Part_5  \
# 0            NaN                 NaN        NaN    Kaggle              NaN
# 1       Twitter                  NaN    Reddit     Kaggle   Course Forums
# 2            NaN  Email newsletters         NaN    Kaggle              NaN
# 3            NaN                 NaN        NaN        NaN             NaN
# 4            NaN                 NaN        NaN        NaN             NaN
# ...          ...                 ...        ...        ...             ...
# 20029        NaN                 NaN        NaN        NaN             NaN
# 20032        NaN                 NaN        NaN        NaN             NaN
# 20033        NaN                 NaN        NaN        NaN             NaN
# 20034   Twitter                  NaN        NaN    Kaggle              NaN
# 20035        NaN                 NaN        NaN    Kaggle   Course Forums
#
#       Q39_Part_6 Q39_Part_7 Q39_Part_8             Q39_Part_9  \
# ...

# %%
#df_12_2 : 12.soru 2.madde için
SocialMframe_12_2 = survey[survey['Age']=='18-21'].filter(regex='^Q39', axis=1)
df_12_2 = pd.DataFrame(SocialMframe_12_2.count(axis=0))
df_12_2.index = SocialMframe_12_2.apply(pd.Series.mode, axis=0).iloc[0]
df_12_2.index.name = 'Social Medias'
df_12_2.columns = ['Count']
df_12_2 = df_12_2.sort_values('Count',ascending=False)
df_12_2.iloc[0]
# Out:
# Count    1062
# Name: Kaggle , dtype: int64

# %% [markdown]
# ## Soru 13:
# * https://download.geonames.org/export/dump/countryInfo.txt adresindeki veriyi:
#     * ilk 49 satırını ihmal ederek
#     * yalnızca ```#ISO, Country, neighbours``` sütunlarını kullanarak
#     * ```Country``` sütununu indeks sütun olarak
#
# okuyarak __country_info__ adlı DataFrame'e aktarınız.
# * ```#ISO``` sütununun ismini ```Country Code``` olarak değiştiriniz.
# * ```survey``` ve ```country_info``` adlı DataFrame'leri ülke bazında birleştirip ```merged_survey``` adında yeni bir dataframe'e aktarınız.

# %%
country_info = pd.read_csv('countryInfo.txt', "\t", skiprows = [i for i in range(0, 49)], usecols=["#ISO", "Country", "neighbours"], index_col= 'Country')
country_info
# Out:
#                       #ISO            neighbours
# Country
# Andorra                 AD                 ES,FR
# United Arab Emirates    AE                 SA,OM
# Afghanistan             AF     TM,CN,IR,TJ,PK,UZ
# Antigua and Barbuda     AG                   NaN
# Anguilla                AI                   NaN
# ...                    ...                   ...
# South Africa            ZA     ZW,SZ,MZ,BW,NA,LS
# Zambia                  ZM  ZW,TZ,MZ,CD,NA,MW,AO
# Zimbabwe                ZW           ZA,MZ,BW,ZM
# Serbia and Montenegro   CS  AL,HU,MK,RO,HR,BA,BG
# Netherlands Antilles    AN                    GP
#
# [252 rows x 2 columns]

# %%
country_info.rename(columns={'#ISO':'Country Code'}, inplace=True)
country_info
# Out:
#                       Country Code            neighbours
# Country
# Andorra                         AD                 ES,FR
# United Arab Emirates            AE                 SA,OM
# Afghanistan                     AF     TM,CN,IR,TJ,PK,UZ
# Antigua and Barbuda             AG                   NaN
# Anguilla                        AI                   NaN
# ...                            ...                   ...
# South Africa                    ZA     ZW,SZ,MZ,BW,NA,LS
# Zambia                          ZM  ZW,TZ,MZ,CD,NA,MW,AO
# Zimbabwe                        ZW           ZA,MZ,BW,ZM
# Serbia and Montenegro           CS  AL,HU,MK,RO,HR,BA,BG
# Netherlands Antilles            AN                    GP
#
# [252 rows x 2 columns]

# %%
merged_survey = survey.merge(country_info, how='inner', on='Country')
merged_survey
# Out:
#          Age Gender    Country  \
# 0      35-39    Man   Colombia
# 1      55-59    Man   Colombia
# 2      18-21    Man   Colombia
# 3      25-29    Man   Colombia
# 4      45-49    Man   Colombia
# ...      ...    ...        ...
# 14788  22-24    Man  Sri Lanka
# 14789  22-24    Man  Sri Lanka
# 14790  22-24    Man  Sri Lanka
# 14791  22-24  Woman  Sri Lanka
# 14792  18-21    Man  Sri Lanka
#
#                                                Education        Occupation  \
# 0                                        Doctoral degree           Student
# 1                                        Master’s degree    Data Scientist
# 2      Some college/university study without earning ...           Student
# 3                                    Professional degree      Data Analyst
# 4                                        Master’s degree  Business Analyst
# ...                                                  ...               ...
# ...

# %% [markdown]
# ## Soru 14:
# Almanya ve komşu ülkeleri için ankete katılanlardan doktoralıların ülke bazında yüzdelerini, ülke isimlerine göre alfabetik sırada listeleyiniz.

# %%
codes = merged_survey[merged_survey['Country']=='Germany']['neighbours'].iloc[0]
df_14 = merged_survey[merged_survey["Country Code"].isin((codes+',DE').split(','))]
df_14
# Out:
#          Age Gender  Country          Education                 Occupation  \
# 7544   35-39    Man  Germany    Doctoral degree             Data Scientist
# 7545   35-39    Man  Germany    Doctoral degree         Research Scientist
# 7546   40-44    Man  Germany    Doctoral degree          Software Engineer
# 7547   25-29  Woman  Germany    Master’s degree             Data Scientist
# 7548   30-34    Man  Germany  Bachelor’s degree                    Student
# ...      ...    ...      ...                ...                        ...
# 12808  25-29    Man   France    Master’s degree                      Other
# 12809  22-24    Man   France    Master’s degree  Machine Learning Engineer
# 12810  22-24    Man   France    Master’s degree             Data Scientist
# 12811  30-34  Woman   France    Master’s degree               Data Analyst
# 12812  45-49    Man   France  Bachelor’s degree             Data Scientist
#
# ...

# %%
df_14_grpd = df_14.groupby('Country')['Education'].value_counts(normalize=True).to_frame()
df_14_grpd
# Out:
#                                                                 Education
# Country     Education
# Belgium     Master’s degree                                      0.644068
#             Doctoral degree                                      0.220339
#             Bachelor’s degree                                    0.101695
#             No formal education past high school                 0.016949
#             Some college/university study without earning a...   0.016949
# France      Master’s degree                                      0.629393
#             Doctoral degree                                      0.239617
#             Bachelor’s degree                                    0.041534
#             Professional degree                                  0.031949
#             I prefer not to answer                               0.019169
#             No formal education past high school                 0.019169
# ...

# %%
df_14_grpd.unstack().reset_index().sort_values(by='Country')['Education']['Doctoral degree'] 
#ülkelerin alfabetik siraya göre doktora derecesi yüzdeleri
# Out:
# 0    0.220339
# 1    0.239617
# 2    0.258486
# 3    0.154362
# 4    0.151724
# 5    0.323529
# Name: Doctoral degree, dtype: float64

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# ## ** Bonus **

# %% [markdown]
# Hedef: Auto-ML yöntemi ile hızlı bir şekilde, Amerikada çalışan data scientistlerin kullandığı kütüphanelerin ve yaşlarının ortalama maaş değişimi üzerine etkisini görsel üzerinden gözlemlemek;

# %% [markdown]
# pycaret autoML kütüphanesi kullanılıyor.

# %% [markdown]
# pycaret kodun sonundaki model explanability görseli için built-in bir şekilde shap kütüphanesini kullanıyor.

# %%
from pycaret.regression import *

# %%
df_bonus = survey2.loc[(survey2['Country']=='United States of America') & (survey2['Occupation']=='Data Scientist')].filter(regex='^Q16', axis=1)        
df_bonus['Age'] = survey2.Age
df_bonus['Salary(mean)'] = survey2.ConvertedComp
df_bonus = df_bonus[df_bonus['Salary(mean)'] != 'nan']
df_bonus = df_bonus.replace(np.nan, 0)
df_bonus
# Out:
#             Q16_Part_1     Q16_Part_2 Q16_Part_3 Q16_Part_4 Q16_Part_5  \
# 3        Scikit-learn     TensorFlow      Keras           0          0
# 115      Scikit-learn               0          0          0          0
# 118      Scikit-learn     TensorFlow      Keras           0          0
# 232      Scikit-learn     TensorFlow           0          0          0
# 306      Scikit-learn               0          0          0          0
# 356                  0              0          0          0          0
# 357      Scikit-learn               0          0          0          0
# 409      Scikit-learn               0          0          0          0
# 529                  0              0          0          0          0
# 533                  0    TensorFlow      Keras           0          0
# 542      Scikit-learn     TensorFlow      Keras           0          0
# 554                  0    TensorFlow           0          0          0
# ...

# %%
df_bonus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 362 entries, 3 to 19038
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Q16_Part_1    362 non-null    object
#  1   Q16_Part_2    362 non-null    object
#  2   Q16_Part_3    362 non-null    object
#  3   Q16_Part_4    362 non-null    object
#  4   Q16_Part_5    362 non-null    object
#  5   Q16_Part_6    362 non-null    object
#  6   Q16_Part_7    362 non-null    object
#  7   Q16_Part_8    362 non-null    object
#  8   Q16_Part_9    362 non-null    object
#  9   Q16_Part_10   362 non-null    object
#  10  Q16_Part_11   362 non-null    object
#  11  Q16_Part_12   362 non-null    object
#  12  Q16_Part_13   362 non-null    object
#  13  Q16_Part_14   362 non-null    object
#  14  Q16_Part_15   362 non-null    object
#  15  Q16_OTHER     362 non-null    object
#  16  Age           362 non-null    object
#  17  Salary(mean)  362 non-null    float64
# ...

# %%
reg = setup(data = df_bonus, 
             target = 'Salary(mean)', train_size = 0.8, fold=10,
             categorical_features = list(df_bonus.columns[:-1].values), silent = True)
# Out:
# <style  type="text/css" >
# </style><table id="T_a42f4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a42f4_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a42f4_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_a42f4_row0_col1" class="data row0 col1" >8197</td>
#             </tr>
#             <tr>
#                         <th id="T_a42f4_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a42f4_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_a42f4_row1_col1" class="data row1 col1" >Salary(mean)</td>
#             </tr>
#             <tr>
# ...

# %%
compare_models() 
# En başarılı sonuç huber reggressor fakat model explanability açısından istediğim çıktıyı almak için(tree-based gerekiyor)
# rf regressor kullanacağım
# Out:
# <style  type="text/css" >
#     #T_b9251_ th {
#           text-align: left;
# ...

# %%
rf_reg = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_d979a_row10_col0,#T_d979a_row10_col1,#T_d979a_row10_col2,#T_d979a_row10_col3,#T_d979a_row10_col4,#T_d979a_row10_col5{
#             background:  yellow;
#         }</style><table id="T_d979a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d979a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d979a_row0_col0" class="data row0 col0" >48216.6502</td>
#                         <td id="T_d979a_row0_col1" class="data row0 col1" >4976814232.3717</td>
# ...

# %%
tuned_rf = tune_model(rf_reg)
# Out:
# <style  type="text/css" >
# #T_fff22_row10_col0,#T_fff22_row10_col1,#T_fff22_row10_col2,#T_fff22_row10_col3,#T_fff22_row10_col4,#T_fff22_row10_col5{
#             background:  yellow;
#         }</style><table id="T_fff22_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fff22_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fff22_row0_col0" class="data row0 col0" >46116.4996</td>
#                         <td id="T_fff22_row0_col1" class="data row0 col1" >5641785006.7400</td>
# ...

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
plot_model(estimator = rf_reg, plot = 'learning') # hyperparameter tuning öncesi learning curve

# %%
plot_model(estimator = tuned_rf, plot = 'learning') # hyperparameter tuning sonrası learning curve

# %%
interpret_model(tuned_rf) #Pycaret kütüphanesi kendi içinde shap kütüphanesini kullanıyor

# %% [markdown]
# 10 KATLI ÇAPRAZ DOĞRULAMA SONUÇLARI:
#
# Facebook'un Prophet algoritması (time series forecast) ve Pytorch maaş yükseltmeye en çok etki yapan kütüphane olarak görülüyor. Klasik ML yöntemlerinden de XGBoost nispeten öne çıkmış.

# %% [markdown]
# **** Aynı analizi Amerika için değil Türkiye için yapalım; ****

# %%
df_bonus_tr = survey2.loc[(survey2['Country']=='Turkey') & (survey2['Occupation']=='Data Scientist')].filter(regex='^Q16', axis=1)        
df_bonus_tr['Age'] = survey2.Age
df_bonus_tr['Salary(mean)'] = survey2.ConvertedComp
df_bonus_tr = df_bonus_tr[df_bonus_tr['Salary(mean)'] != 'nan']
df_bonus_tr = df_bonus_tr.replace(np.nan, 0)
df_bonus_tr
# Out:
#             Q16_Part_1     Q16_Part_2 Q16_Part_3 Q16_Part_4 Q16_Part_5  \
# 152      Scikit-learn     TensorFlow      Keras    PyTorch    Fast.ai
# 641      Scikit-learn     TensorFlow           0          0          0
# 704      Scikit-learn     TensorFlow      Keras           0          0
# 1480     Scikit-learn               0          0          0          0
# 1594     Scikit-learn     TensorFlow      Keras           0          0
# 2705     Scikit-learn     TensorFlow      Keras    PyTorch           0
# 3522     Scikit-learn     TensorFlow      Keras    PyTorch           0
# 3913     Scikit-learn     TensorFlow           0          0          0
# 4073     Scikit-learn     TensorFlow      Keras           0          0
# 4448     Scikit-learn               0          0          0          0
# 6128     Scikit-learn     TensorFlow      Keras    PyTorch           0
# 6226     Scikit-learn               0          0          0          0
# ...

# %%
reg_tr = setup(data = df_bonus_tr, 
             target = 'Salary(mean)', train_size = 0.8, fold=10,
             categorical_features = list(df_bonus.columns[:-1].values), silent = True)
# Out:
# <style  type="text/css" >
# </style><table id="T_debee_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_debee_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_debee_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_debee_row0_col1" class="data row0 col1" >4675</td>
#             </tr>
#             <tr>
#                         <th id="T_debee_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_debee_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_debee_row1_col1" class="data row1 col1" >Salary(mean)</td>
#             </tr>
#             <tr>
# ...

# %%
compare_models() 
# En başarılı sonuç huber reggressor fakat model explanability açısından istediğim çıktıyı almak için(tree-based gerekiyor)
# rf regressor kullanacağım
# Out:
# <style  type="text/css" >
#     #T_aa434_ th {
#           text-align: left;
# ...

# %%
rf_reg_tr = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_6018f_row10_col0,#T_6018f_row10_col1,#T_6018f_row10_col2,#T_6018f_row10_col3,#T_6018f_row10_col4,#T_6018f_row10_col5{
#             background:  yellow;
#         }</style><table id="T_6018f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6018f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6018f_row0_col0" class="data row0 col0" >24620.0000</td>
#                         <td id="T_6018f_row0_col1" class="data row0 col1" >1699800550.0000</td>
# ...

# %%
tuned_rf_tr = tune_model(rf_reg_tr)
# Out:
# <style  type="text/css" >
# #T_37f6d_row10_col0,#T_37f6d_row10_col1,#T_37f6d_row10_col2,#T_37f6d_row10_col3,#T_37f6d_row10_col4,#T_37f6d_row10_col5{
#             background:  yellow;
#         }</style><table id="T_37f6d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_37f6d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_37f6d_row0_col0" class="data row0 col0" >29640.4412</td>
#                         <td id="T_37f6d_row0_col1" class="data row0 col1" >2886627912.5216</td>
# ...

# %%
evaluate_model(tuned_rf_tr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
interpret_model(tuned_rf_tr) #Pycaret kütüphanesi kendi içinde shap kütüphanesini kullanıyor
