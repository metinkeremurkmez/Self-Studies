# %%
class bigquery_patterns:
    
    import unidecode    
    
    def __init__(self, list_attribute_key = None, list_label = None, list_attribute = None, list_general = None, list_label_2 = None, list_label_3 = None, list_label_4 = None, list_label_5 = None, list_label_6 = None):

        self.list_attribute_key = list_attribute_key
        self.list_label = list_label
        self.list_attribute = list_attribute
        self.list_general = list_general
        self.list_label_2 = list_label_2
        self.list_label_3 = list_label_3
        self.list_label_4 = list_label_4
        self.list_label_5 = list_label_5
        self.list_label_6 = list_label_6
   
    def opening_attributes_string_category_click(self):
        
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "category_click"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i) + '_category_click' +',\n')
        
    def opened_attributes_labelling_category_click(self):
        
        for i in self.list_label:
            print('COUNT (CASE')
            print('WHEN ' 'fields_category_click' + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                   ' ' +'"' + '{}'.format(i) + '"')
            print('ELSE NULL END) AS ' + 'category_click_' + ('{}'.format(i)).lower()+',\n')
               
    
    ##
    
    def opening_attributes_string_so_anasayfa_goruntuleme(self): 
        
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "so_anasayfa_goruntuleme"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i) +'_so_anasayfa_goruntuleme' +',\n')
    
    def opened_attributes_labelling_so_anasayfa_goruntuleme(self):
        
        for i in self.list_label:
            print('COUNT (CASE')
            print('WHEN ' 'firebase_screen_so_anasayfa_goruntuleme' + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                   ' ' +'"' + '{}'.format(i) + '"')
            print('ELSE NULL END) AS ' + 'so_anasayfa_goruntuleme_' + self.unidecode.unidecode('{}'.format(i)).replace(" ", "").replace(":", "_").lower() +',\n') 
                
    
    ##
 
    def opening_attributes_string_reklam_takibi_onaylayanlar(self):
        
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "reklam_takibi_onaylayanlar"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i) + '_reklam_takibi_onaylayanlar' +',\n')
    
    def opened_attributes_labelling_reklam_takibi_onaylayanlar(self):
        
        for i in self.list_label:
            print('COUNT (CASE')
            print('WHEN ' 'firebase_screen_reklam_takibi_onaylayanlar' + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                   ' ' +'"' + '{}'.format(i) + '"')
            print('ELSE NULL END) AS ' + 'reklam_takibi_onaylayanlar_' + self.unidecode.unidecode('{}'.format(i)).replace(" ", "").replace(":", "_").lower() +',\n') 
    
    ##
    
    def opening_attributes_string_affiliate_tab_anasayfa_goruntuleme(self):
        
        list_temp = []
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "affiliate_tab_anasayfa_goruntulenme"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i)  +'_affiliate_tab_anasayfa_goruntulenme' +',\n')
            list_temp.append('{}'.format(i) + '_affiliate_tab_anasayfa_goruntulenme')
        return list_temp,
    
     
    def opened_attributes_labelling_affiliate_tab_anasayfa_goruntuleme(self, list_temp):
        counter = 0
        for x in list_temp:
            for i in (self.list_label)[counter]:
                print('COUNT (CASE')
                print('WHEN ' + '{}'.format(x) + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                       ' ' +'"' + '{}'.format(i) + '"')
                print('ELSE NULL END) AS ' + '{}'.format(x) + '_' + self.unidecode.unidecode('{}'.format(i)).replace(" ", "").replace(":", "_").lower() +',\n')    
            counter = counter + 1
        
        
    ##
    
    def opening_attributes_string_player_percent_played_95(self):
        
        list_temp = []
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "player_percent_played_95"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i)  +'_player_percent_played_95' +',\n')
            list_temp.append('{}'.format(i) + '_player_percent_played_95')
        return list_temp,
    
     
    def opened_attributes_labelling_player_percent_played_95(self, list_temp):
        counter = 0
        for x in list_temp:
            for i in (self.list_label)[counter]:
                print('COUNT (CASE')
                print('WHEN ' + '{}'.format(x) + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                       ' ' +'"' + '{}'.format(i) + '"')
                print('ELSE NULL END) AS ' + '{}'.format(x) + '_' + self.unidecode.unidecode('{}'.format(i)).replace(" ", "").replace(":", "_").lower() +',\n')    
            counter = counter + 1
        
    ##
    
    def opening_attributes_string_player_percent_played_25(self):
        
        list_temp = []
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "player_percent_played_95"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i)  +'_player_percent_played_25' +',\n')
            list_temp.append('{}'.format(i) + '_player_percent_played_25')
        return list_temp,
    
       
    def opened_attributes_labelling_player_percent_played_25(self, list_temp):
        counter = 0
        for x in list_temp:
            for i in (self.list_label)[counter]:
                print('COUNT (CASE')
                print('WHEN ' + '{}'.format(x) + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                       ' ' +'"' + '{}'.format(i) + '"')
                print('ELSE NULL END) AS ' + '{}'.format(x) + '_' + self.unidecode.unidecode('{}'.format(i)).replace(" ", "").replace(":", "_").lower() +',\n')    
            counter = counter + 1
        
    ##
    
    def opening_attributes_string_player_start(self):
        
        list_temp = []
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "player_start"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i)  +'_player_start' +',\n')
            list_temp.append('{}'.format(i) + '_player_start')
        return list_temp,
    
     
    def opened_attributes_labelling_player_start(self, list_temp):
        counter = 0
        for x in list_temp:
            for i in (self.list_label)[counter]:
                print('COUNT (CASE')
                print('WHEN ' + '{}'.format(x) + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                       ' ' +'"' + '{}'.format(i) + '"')
                print('ELSE NULL END) AS ' + '{}'.format(x) + '_' + self.unidecode.unidecode('{}'.format(i)).replace(" ", "").replace(":", "_").lower() +',\n')    
            counter = counter + 1
            
            
            
    ##
    
    def opening_attributes_string_so_gazeteler_gazeteokuma(self):
        
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "so_gazeteler_gazeteokuma"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i) + '_so_gazeteler_gazeteokuma' +',\n')   
           
    def opened_attributes_labelling_so_gazeteler_gazeteokuma(self):
        
        counter = 1
        for x in self.list_label:
            x = list(map(lambda i: (self.unidecode.unidecode(i).replace(" ", "_").lower()), x))
            body = ' '.join(['LIKE' + ' ' + '"%' +  str(elem) + '%' + ' ' + 'OR'  if not x[-1] == elem else 'LIKE' + ' ' + '"%' +  str(elem) + '%' for elem in x])
            query = 'COUNT(CASE WHEN ad_so_gazeteler_gazeteokuma ' + str(body) + ' THEN ' + 'grup_' + str(counter) + '_gazete' + ' ELSE NULL END) AS news_paper_group' + str(counter) +','
            print(query, '\n')
            counter = counter + 1
            
    ##
    
    
    def opening_attributes_string_so_genel_widget_detaya_gitme(self):
        
        list_temp = []
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "so_genel_widget_detaya_gitme"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i)  +'_so_genel_widget_detaya_gitme' +',\n')
            list_temp.append('{}'.format(i) + '_so_genel_widget_detaya_gitme')
        return list_temp,
    
    
    def opened_attributes_labelling_so_genel_widget_detaya_gitme(self, list_temp):
        counter = 0
        for x in list_temp:
            for i in (self.list_label)[counter]:
                print('COUNT (CASE')
                print('WHEN ' + '{}'.format(x) + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                       ' ' +'"' + '{}'.format(i) + '"')
                print('ELSE NULL END) AS ' + '{}'.format(x) + '_' + self.unidecode.unidecode('{}'.format(i)).replace(" ", "").replace(":", "_").lower() +',\n')    
            counter = counter + 1
            
    ##
    
    def opening_attributes_string_footer_share_click(self):
        
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "footer_share_click"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i) + '_footer_share_click' +',\n')
    
    def opened_attributes_labelling_footer_share_click(self):
        
        for i in self.list_label:
            print('COUNT (CASE')
            print('WHEN ' 'name_footer_share_click' + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                   ' ' +'"' + '{}'.format(i) + '"')
            print('ELSE NULL END) AS ' + 'footer_share_click_' + self.unidecode.unidecode('{}'.format(i)).replace(" ", "").lower() +',\n')
            
    ##
    
    def opening_attributes_string_affiliate_click(self):
        
        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "affiliate_click"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '"' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}'.format(i) + '_affiliate_click' +',\n')
    
    def opened_attributes_labelling_affiliate_click(self):
        
        for i in self.list_label:
            print('COUNT (CASE')
            print('WHEN ' 'item_category_affiliate_click' + ' ' 'LIKE' + ' ' + '"%' + '{}'.format(i) + '%"' + ' ' + 'THEN' + 
                   ' ' +'"' + '{}'.format(i) + '"')
            print('ELSE NULL END) AS ' + 'affiliate_click_' + self.unidecode.unidecode('{}'.format(i)).replace("-", "_").replace(" ", "").lower() +',\n')
            
            

################################
            
    def opening_attributes_int(self):
        
        for i in self.list_attribute:
            print('CASE WHEN event_name = ' + '"'  + '{}'.format(i) + '"' + ' ' 
                  + 'THEN (SELECT value.int_value FROM UNNEST(event_params) WHERE KEY = ' + 'firebase_screen' 
                  + '"' ') ' + ' ' + 'ELSE 0 END AS' + ' ' + '{}\n')
    
    def opening_attributes_string_content_view(self):

        for i in self.list_attribute_key:
            print('CASE WHEN event_name = "content_view"' + ' ' 
                  + 'THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = ' + '{}'.format(i) 
                  + '"' ') ' + ' ' + 'ELSE NULL END AS' + ' ' + '{}\n')

    def opened_attributes_labelling_content_view(self):
        print('CASE\n')
        for i in list_label:
            if i == 'yurthaber':
                print('WHEN content_view_categorytree LIKE "%Yurt%"')
                for j in list_label_4:
                    print('OR' + ' ' + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%' + '{}'.format(j) + 
                          '%' + '"')
                print('THEN' + '{}')
            
            if i == 'spor':
                print('WHEN LOWER(content_view_categorytree) LIKE "%spor%"')
                for k in list_label_5:
                    print('OR' + ' ' + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%' + '{}'.format(k) + 
                          '%' + '"')
                print('THEN' + '{}')
            if i == 'Haber':
                print('WHEN content_view_categorytree LIKE "%Haber%"')
                for z in list_label_6:
                    print('OR' + ' ' + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%' + '{}'.format(z) + 
                          '%' + '"')
                print('THEN' + '{}')
            else:
                print('WHEN LOWER(' 'content_view_categorytree' + ')' + ' ' + 'LIKE' + ' '+ '"' +'%'  + 
                  '{}'.format(i)  +'%' + '"' + ' ' + 'THEN' + 
                   ' ' +'"' + '{}'.format(i) + '"')
        print('ELSE NULL END AS')
    
    def opened_attributes_nested_labelling_content_view_1(self):
        print('CASE\n')
        for i in self.list_general:
            for j in list_label:
                print('WHEN content_view_screen_name = ' + '"' +'{}'.format(i) + '"' +' ' + 'AND' + ' ' 
                      + 'content_view_detail_category' + ' ' + 'LIKE' + ' ' + '"' + '%'  + '{}'.format(j) +'%' + '"' 
                       ' ' + 'THEN' + ' '+ '"' + '{}'.format(j) + '"')
        print('ELSE NULL END AS')
        
    def opened_attributes_nested_labelling_content_view_1_general(self):
        print('CASE\n')
        for i in self.list_general:
            for j in list_label:
                print('WHEN content_view_screen_name = ' + '"' +'{}'.format(i) + '"' +' ' + 'AND' + ' ' 
                      + 'content_view_detail_category' + ' ' + 'LIKE' + ' ' + '"' + '%'  + '{}'.format(j) +'%' + '"' 
                       + ' ' + 'OR')
            print(' THEN' + '"' +' ' + '"')
        print('ELSE NULL END AS')
    def opened_attributes_nested_labelling_categoryTree_2(self):
        print('CASE\n')
        print('WHEN\n')
        for i in list_general:
            for j in list_label_2:
                print('content_view_general_category = ' + '"' + '{}'.format(i) + '"' + ' ' + 'AND' + ' '
                     + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%' + '{}'.format(j) + '%' + '"' + 'OR' + ' ')
        print('THEN ' + '"{}"')
        
        for i in list_general:
            for j in list_label_3:
                print('content_view_general_category = ' + '"' + '{}'.format(i) + '"' + ' ' + 'AND' + ' '
                     + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%' + '{}'.format(j) + '%' + '"' + 'OR' + ' ')
        print('THEN ' + '"{}"')
        
        for i in self.list_general:
            for j in list_label:
                print('WHEN content_view_general_category = ' + '"' +'{}'.format(i) + '"' +' ' + 'AND' + ' ' 
                      + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%'  + '{}'.format(j) +'%' + '"' 
                       ' ' + 'THEN' + ' '+ '"' + '{}'.format(j) + '"')
        print('ELSE NULL END AS')
    
    def opened_attributes_nested_labelling_categoryTree_1(self):
        print('CASE\n')
        for i in self.list_general:
            for j in list_label:
                print('WHEN content_view_general_category = ' + '"' +'{}'.format(i) + '"' +' ' + 'AND' + ' ' 
                      + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%'  + '{}'.format(j) +'%' + '"' 
                       ' ' + 'THEN' + ' '+ '"' + '{}'.format(j) + '"')
        print('ELSE NULL END AS')
        
    def opened_attributes_nested_labelling_categoryTree_2_2(self):
        print('CASE\n')
        print('WHEN\n')
        for i in list_general:
            for j in list_label_2:
                print('spor_segments_general = ' + '"' + '{}'.format(i) + '"' + ' ' + 'AND' + ' '
                     + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%' + '{}'.format(j) + '%' + '"' + 'OR' + ' ')
        print('THEN ' + '"{}"')
        
        for i in list_general:
            for j in list_label_3:
                print('content_view_general_category = ' + '"' + '{}'.format(i) + '"' + ' ' + 'AND' + ' '
                     + 'content_view_categorytree' + ' ' + 'LIKE' + ' ' + '"' + '%' + '{}'.format(j) + '%' + '"' + 'OR' + ' ')
        print('THEN ' + '"{}"')
        
    def sumation_msecs(self):
        
        for i in self.list_label:
            print('SUM(' + '{}'.format(i) +')' + ' ' + 'AS' + ' ' +'firebase_screen_msec_' + '{}'.format(i))
            
            
def main():
        
    print("--QUERIES\n")
        
    #### category_click
    bq = bigquery_patterns( list_attribute_key = ['item_category'],
    list_label = ['Mynet - Yaşam',
    'Mynet - Teknoloji',
    'Mynet - Gündem',
    #Gezi Seyahat
    #En Yeniler
    'Mynet - Kadın',
    #Moda
    'Mynet - Yemek',
    #Teknoloji
    'Mynet - Eğitim',
    #Ev Yaşam
    ])
        
    bq.opening_attributes_string_affiliate_click()
    bq.opened_attributes_labelling_affiliate_click()
        
    #### footer_share_click
    bq = bigquery_patterns(list_attribute_key = ['name'],
    list_label = ['whatsapp','activity','comment','facebook','twitter'])
        
    bq.opening_attributes_string_footer_share_click()
    bq.opened_attributes_labelling_footer_share_click()
      
        
    #### so_genel_widget_detaya_gitme        
    bq = bigquery_patterns(list_attribute_key = ['tip', 'firebase_screen', 'category_name'],
    list_label = [['namazvakti',
        'finans',
        'gununsozu',
        'astroloji',
        'gazeteler']
        ,
        ['Kategori : Size Özel',
        'Kategori : Politika',
        'Kategori : Sinema',
        'Kategori : Teknoloji',
        'Kategori : Dünya',
        'Kategori : Seyahat',
        'Kategori : Eğitim',
        'Kategori : Yemek',
        'Kategori : Yaşam',
        'Kategori : Finans',
        'Kategori : Spor',
        'Kategori : Kadın',
        'Kategori : Oyun',
        'Kategori : Gündem',
        #Detay : Kadın
        'Kategori : Magazin',
        'Kategori : Trend'],
        ['Sinema',
        'Trend',
        'Spor',
        'Teknoloji',
        'Kadın',
        'Politika',
        'Yemek',
        'Dünya',
        'Eğitim',
        'Oyun',
        'Yaşam',
        'Gündem',
        'Seyahat',
        'Magazin',
        'Finans'
        ]])
        
    opening = bq.opening_attributes_string_so_genel_widget_detaya_gitme()
    print(opening[0])
    bq.opened_attributes_labelling_so_genel_widget_detaya_gitme(opening[0])
        
   
        
    bq.opening_attributes_string_so_gazeteler_gazeteokuma()
    bq.opened_attributes_labelling_so_gazeteler_gazeteokuma()
        
    #### category_click
    bq = bigquery_patterns(list_attribute_key = ['firebase_screen'],
    list_label = ['Kategori : Size Özel',
        'Kategori : Politika',
        'Kategori : Sinema',
        'Kategori : Teknoloji',
        'Kategori : Dünya',
        'Kategori : Seyahat',
        'Kategori : Eğitim',
        'Kategori : Yemek',
        'Kategori : Yaşam',
        'Kategori : Finans',
        'Kategori : Spor',
        'Kategori : Kadın',
        'Kategori : Oyun',
        'Kategori : Gündem',
        #'Detay : Kadın',
        'Kategori : Magazin',
        'Kategori : Trend'])
        
    bq.opening_attributes_string_category_click() 
    bq.opened_attributes_labelling_category_click()
        
    #### so_anasayfa_goruntuleme
    bq = bigquery_patterns(list_attribute_key = ['firebase_screen'],
    list_label = ['Detay : Politika',
        'Detay : Dünya',
        #'Kategori : Teknoloji',
        #'Kategori : Sinema',
        #Ayarlar
        #'Kategori : Yemek',
        #'Son Dakika',
        'Detay : Yaşam',
        #'Günün Özeti',
        'Detay : Kadın',
        'Detay : Magazin',
        #'Kategori : Magazin',
        'Detay : Yemek',
        #'Kategori : Size Özel',
        #'Kategori : Dünya',
        #'Kategori : Oyun',
        'Detay : Finans',
        'Detay : Güncel',
        #'Kategori : Spor',
        'Yurt Haber',
        #'Kategori : Seyahat',
        #'Kategori : Finans',
        #'Kategori : Trend',
        #Videolar
        'Detay : İlginç Haberler',
        #'Kategori : Eğitim',
        #'Kategori : Gündem',
        #'Kategori : Yaşam',
        #Bildirimler
        'Detay : Spor',
        #'Kategori : Kadın',
        #'Kategori : Politika',
        'Detay : Eğitim',
        'Detay : Sağlık',
        'Detay : Trend'])
        
    bq.opening_attributes_string_so_anasayfa_goruntuleme()    
    bq.opened_attributes_labelling_so_anasayfa_goruntuleme()
        
    #### reklam_takibi_onaylayanlar
    bq = bigquery_patterns(list_attribute_key = ['firebase_screen'],
    list_label = ['Detay : Güncel', 'Detay : Spor'])
        
    bq.opening_attributes_string_reklam_takibi_onaylayanlar()
    bq.opened_attributes_labelling_reklam_takibi_onaylayanlar()
        
    #### affiliate_tab_anasayfa_goruntuleme
    bq = bigquery_patterns(list_attribute_key = ['item_category','firebase_screen'],
    list_label = [['Gezi Seyahat',
        'Eğlence',
        'Kişisel Bakım',
        'Hediye Rehberi',
        'İndirim',
        'Moda',
        'Ev Yaşam',
        'En Yeniler',
        'Spor',
        'Teknoloji',
        'Anne Çocuk'],['Detay : İstanbul/Interstitial',
        'Detay : Yemek',
        'Detay : Teknoloji',
        'Detay : Dünya',
        'Detay : Kadın',
        'Detay : Sağlık',
        'Detay : Yaşam',
        'Detay : Spor',
        'Detay : Politika',
        'Detay : Magazin',
        'Detay : Güncel',
        'Detay : Otomobil',
        'Detay : Finans',]])
        
    opening = bq.opening_attributes_string_affiliate_tab_anasayfa_goruntuleme()
    bq.opened_attributes_labelling_affiliate_tab_anasayfa_goruntuleme(opening[0])
        
    #### player_percent_played_95
    bq = bigquery_patterns(list_attribute_key = ['videoPublisherName', 'firebase_screen'],
    list_label = [['Mynet Finans',
        'Mynet Spor',
        'Mynet Kadın',
        'Mynet Haber',
        'Mynet Trend',
        'Mynet Magazin'],[
        'Detay : Spor',
        'Detay : Sağlık',
        'Detay : Yaşam',
        'Detay : Dünya',
        #'Kategori : Gündem',
        'Detay : Politika',
        'Detay : Yemek',
        'Detay : Kadın',
        'Detay : Güncel',
        'Detay : Finans',
        'Detay : Magazin',
        'Detay : İlginç Haberler']])
        
    opening = bq.opening_attributes_string_player_percent_played_95()
    bq.opened_attributes_labelling_player_percent_played_95(opening[0])
        
    #### player_percent_played_25
    bq = bigquery_patterns(list_attribute_key = ['videoPublisherName', 'firebase_screen'],
    list_label = [['Mynet Finans',
        'Mynet Spor',
        'Mynet Kadın',
        'Mynet Haber',
        'Mynet Trend',
        'Mynet Magazin'],[
        'Detay : Spor',
        'Detay : Sağlık',
        'Detay : Yaşam',
        'Detay : Dünya',
        #'Kategori : Gündem',
        'Detay : Politika',
        'Detay : Yemek',
        'Detay : Kadın',
        'Detay : Güncel',
        'Detay : Finans',
        'Detay : Magazin',
        'Detay : İlginç Haberler']])
        
    opening = bq.opening_attributes_string_player_percent_played_25()
    bq.opened_attributes_labelling_player_percent_played_25(opening[0])
     
    #### player_start
    bq = bigquery_patterns(list_attribute_key = ['videoPublisherName','videoChannelName', 'firebase_screen'],
        list_label = [['Mynet Finans',
        'Mynet Magazin',
        'Mynet Haber',
        'Mynet Trend',
        'Mynet Spor',
        'Mynet Kadın'],
        [
        'İhlas Haber Ajansı',
        'Dizi Fragmanları',
        'Anadolu Ajansı',
        'Kanal Finans',
        'Birbak Magazin',
        'Doğan Haber Ajansı'],
        [
        'Detay : Magazin',
        'Detay : Politika',
        'Detay : Yaşam',
        'Detay : Spor',
        'Detay : Kadın',
        'Detay : İlginç Haberler',
        'Detay : Dünya',
        'Detay : Finans',
        'Detay : Güncel',
        'Detay : Yemek',
        'Detay : Trend',
        #'Kategori : Gündem',
        #'Son Dakika'
    ]])
    opening = bq.opening_attributes_string_player_start()
    bq.opened_attributes_labelling_player_start(opening[0])
          
if __name__ == '__main__':
    main()
# Out:
# --QUERIES
#
# CASE WHEN event_name = "affiliate_click" THEN (SELECT value.string_value FROM UNNEST(event_params) WHERE KEY = "item_category")  ELSE NULL END AS item_category_affiliate_click,
#
# COUNT (CASE
# WHEN item_category_affiliate_click LIKE "%Mynet - Yaşam%" THEN "Mynet - Yaşam"
# ELSE NULL END) AS affiliate_click_mynet_yasam,
#
# COUNT (CASE
# WHEN item_category_affiliate_click LIKE "%Mynet - Teknoloji%" THEN "Mynet - Teknoloji"
# ELSE NULL END) AS affiliate_click_mynet_teknoloji,
#
# COUNT (CASE
# WHEN item_category_affiliate_click LIKE "%Mynet - Gündem%" THEN "Mynet - Gündem"
# ELSE NULL END) AS affiliate_click_mynet_gundem,
#
# COUNT (CASE
# WHEN item_category_affiliate_click LIKE "%Mynet - Kadın%" THEN "Mynet - Kadın"
# ELSE NULL END) AS affiliate_click_mynet_kadin,
#
# COUNT (CASE
# WHEN item_category_affiliate_click LIKE "%Mynet - Yemek%" THEN "Mynet - Yemek"
# ELSE NULL END) AS affiliate_click_mynet_yemek,
#
# COUNT (CASE
# ...
